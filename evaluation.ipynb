# %% [markdown]
# ### evaluation on market data

# %%
# !python marketDataTest.py
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# -------test-----------
# Using 4 GPUs for inference
# 19732it [02:13, 147.87it/s]
# 3374it [00:22, 152.17it/s]
# Training complete in 2m 35.62s
# clip-vit-base-patch16-finetuned

# %%
# !python marketEvaluate_gpu.py
# Out:
# torch.Size([3374, 768])
# Rank@1:0.338174 Rank@5:0.534973 Rank@10:0.621814 mAP:0.146055

# %%
# !python marketDataTest.py --name 'clip-vit-base-patch16-finetuned' 
# !python marketEvaluate_gpu.py --name 'clip-vit-base-patch16-finetuned'
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# -------test-----------
# Using 4 GPUs for inference
# 19732it [02:11, 149.49it/s]
# 3374it [00:21, 154.11it/s]
# Training complete in 2m 33.89s
# clip-vit-base-patch16-finetuned
# torch.Size([3374, 768])
# Rank@1:0.338174 Rank@5:0.534973 Rank@10:0.621814 mAP:0.146055

# %%
# !python marketDataTest.py --name 'openai/clip-vit-base-patch16' --usePretrain True
# !python marketEvaluate_gpu.py --name 'openai/clip-vit-base-patch16'
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# -------test-----------
# Using 4 GPUs for inference
# 19732it [02:11, 150.12it/s]
# 3374it [00:21, 154.55it/s]
# Training complete in 2m 33.28s
# openai/clip-vit-base-patch16
# torch.Size([3374, 768])
# Rank@1:0.120925 Rank@5:0.227623 Rank@10:0.296681 mAP:0.029882

# %%
# !python marketDataTest.py --name 'clip-vit-base-patch16-finetuned-3epoch' 
# !python marketEvaluate_gpu.py --name 'clip-vit-base-patch16-finetuned-3epoch'
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# -------test-----------
# Using 4 GPUs for inference
# 19732it [02:10, 150.64it/s]
# 3374it [00:21, 154.08it/s]
# Training complete in 2m 32.89s
# clip-vit-base-patch16-finetuned-3epoch
# torch.Size([3374, 768])
# Rank@1:0.353290 Rank@5:0.534084 Rank@10:0.619739 mAP:0.146386

# %%
# !python marketDataTest.py --name 'clip-vit-base-patch16-finetuned-1epoch-freeze_text'
# !python marketEvaluate_gpu.py --name 'clip-vit-base-patch16-finetuned-1epoch-freeze_text'
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# -------test-----------
# Using 4 GPUs for inference
# 19732it [02:43, 120.45it/s]
# 3374it [00:22, 151.92it/s]
# Training complete in 3m 6.03s
# clip-vit-base-patch16-finetuned-1epoch-freeze_text
# torch.Size([3374, 768])
# Rank@1:0.354179 Rank@5:0.541197 Rank@10:0.631298 mAP:0.150359

# %%
# !python marketDataTest.py --name 'clip-vit-base-patch16-finetuned-3epoch-freeze_text'
# !python marketEvaluate_gpu.py --name 'clip-vit-base-patch16-finetuned-3epoch-freeze_text'
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# -------test-----------
# Using 4 GPUs for inference
# 19732it [02:45, 119.37it/s]
# 3374it [00:22, 152.23it/s]
# Training complete in 3m 7.47s
# clip-vit-base-patch16-finetuned-3epoch-freeze_text
# torch.Size([3374, 768])
# Rank@1:0.344398 Rank@5:0.537344 Rank@10:0.622999 mAP:0.141893

# %%
# !python marketDataTest.py --name 'swinv2-base-roberta-finetuned-1epoch' --useSwin True --batchsize 128
# !python marketEvaluate_gpu.py --name 'swinv2-base-roberta-finetuned-1epoch'
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# -------test-----------
# Using 4 GPUs for inference
# 19732it [03:11, 102.85it/s]
# 3374it [00:29, 112.71it/s]
# Training complete in 3m 41.80s
# swinv2-base-roberta-finetuned-1epoch
# torch.Size([3374, 1024])
# Rank@1:0.209840 Rank@5:0.400415 Rank@10:0.494665 mAP:0.091536

# %%
# !python marketDataTest.py --name 'swinv2-base-roberta-finetuned-3epoch' --useSwin True --batchsize 128
# !python marketEvaluate_gpu.py --name 'swinv2-base-roberta-finetuned-3epoch'
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# -------test-----------
# Using 4 GPUs for inference
# 19732it [02:29, 131.91it/s]
# 3374it [00:25, 132.93it/s]
# Training complete in 2m 54.97s
# swinv2-base-roberta-finetuned-3epoch
# torch.Size([3374, 1024])
# Rank@1:0.239775 Rank@5:0.436870 Rank@10:0.529935 mAP:0.102055

# %% [markdown]
# ### evaluation on customer data

# %%
# !python customer_reid_evalution.py --name 'openai/clip-vit-base-patch16' --usePretrain True
# Out:
# Using 4 GPUs for inference
# Extracting lib features ...
# 100%|█████████████████████████████████████████| 132/132 [00:03<00:00, 38.75it/s]
# Extracting lib features done
# Processing hb3: rawdata/customer/images/T8030P132210002A
# ...
# 100%|█████████████████████████████████████████| 183/183 [06:09<00:00,  2.02s/it]
# Processing hb3: rawdata/customer/images/T8030P13221000E6
# 100%|█████████████████████████████████████████| 279/279 [05:37<00:00,  1.21s/it]
# Precision: 87 / 462 = 0.19
# Recall: 87 / 462 = 0.19

# %%
# !python customer_reid_evalution.py --name 'clip-vit-base-patch16-finetuned'
# Out:
# Using 4 GPUs for inference
# Extracting lib features ...
# 100%|█████████████████████████████████████████| 132/132 [00:02<00:00, 48.56it/s]
# Extracting lib features done
# Processing hb3: rawdata/customer/images/T8030P132210002A
# ...
# 100%|█████████████████████████████████████████| 183/183 [06:00<00:00,  1.97s/it]
# Processing hb3: rawdata/customer/images/T8030P13221000E6
# 100%|█████████████████████████████████████████| 279/279 [05:28<00:00,  1.18s/it]
# Precision: 115 / 462 = 0.25
# Recall: 115 / 462 = 0.25

# %%
# !python customer_reid_evalution.py --name 'clip-vit-base-patch16-finetuned-3epoch'
# Out:
# Using 4 GPUs for inference
# Extracting lib features ...
# 100%|█████████████████████████████████████████| 132/132 [00:02<00:00, 48.45it/s]
# Extracting lib features done
# Processing hb3: rawdata/customer/images/T8030P132210002A
# ...
# 100%|█████████████████████████████████████████| 183/183 [06:01<00:00,  1.97s/it]
# Processing hb3: rawdata/customer/images/T8030P13221000E6
# 100%|█████████████████████████████████████████| 279/279 [05:28<00:00,  1.18s/it]
# Precision: 116 / 462 = 0.25
# Recall: 116 / 462 = 0.25

# %%
# !python customer_reid_evalution.py --name 'clip-vit-base-patch16-finetuned-1epoch-freeze_text'
# Out:
# Using 4 GPUs for inference
# Extracting lib features ...
# 100%|█████████████████████████████████████████| 132/132 [00:03<00:00, 34.19it/s]
# Extracting lib features done
# Processing hb3: rawdata/customer/images/T8030P132210002A
# ...
# 100%|█████████████████████████████████████████| 183/183 [07:46<00:00,  2.55s/it]
# Processing hb3: rawdata/customer/images/T8030P13221000E6
# 100%|█████████████████████████████████████████| 279/279 [06:33<00:00,  1.41s/it]
# Precision: 110 / 462 = 0.24
# Recall: 110 / 462 = 0.24

# %%
# !python customer_reid_evalution.py --name 'clip-vit-base-patch16-finetuned-3epoch-freeze_text'
# Out:
# Using 4 GPUs for inference
# Extracting lib features ...
# 100%|█████████████████████████████████████████| 132/132 [00:03<00:00, 39.19it/s]
# Extracting lib features done
# Processing hb3: rawdata/customer/images/T8030P132210002A
# ...
# 100%|█████████████████████████████████████████| 183/183 [07:15<00:00,  2.38s/it]
# Processing hb3: rawdata/customer/images/T8030P13221000E6
# 100%|█████████████████████████████████████████| 279/279 [06:38<00:00,  1.43s/it]
# Precision: 108 / 462 = 0.23
# Recall: 108 / 462 = 0.23

# %%
# !python customer_reid_evalution.py --name 'swinv2-base-roberta-finetuned-1epoch' --useSwin True
# Out:
# Using 4 GPUs for inference
# Extracting lib features ...
# 100%|█████████████████████████████████████████| 132/132 [00:09<00:00, 13.36it/s]
# Extracting lib features done
# Processing hb3: rawdata/customer/images/T8030P132210002A
# ...
# 100%|█████████████████████████████████████████| 183/183 [19:37<00:00,  6.43s/it]
# Processing hb3: rawdata/customer/images/T8030P13221000E6
# 100%|█████████████████████████████████████████| 279/279 [17:30<00:00,  3.77s/it]
# Precision: 125 / 462 = 0.27
# Recall: 125 / 462 = 0.27

# %%
# !python customer_reid_evalution.py --name 'swinv2-base-roberta-finetuned-3epoch' --useSwin True
# Out:
# Using 4 GPUs for inference
# Extracting lib features ...
# 100%|█████████████████████████████████████████| 132/132 [00:08<00:00, 15.98it/s]
# Extracting lib features done
# Processing hb3: rawdata/customer/images/T8030P132210002A
# ...
# 100%|█████████████████████████████████████████| 183/183 [15:56<00:00,  5.23s/it]
# Processing hb3: rawdata/customer/images/T8030P13221000E6
# 100%|█████████████████████████████████████████| 279/279 [14:23<00:00,  3.10s/it]
# Precision: 126 / 462 = 0.27
# Recall: 126 / 462 = 0.27

# %% [markdown]
# ### tmp

# %%
from torchvision import datasets
import os
data_dir = './rawdata/Market-1501-v15.09.15/pytorch'
image_datasets = {x: datasets.ImageFolder( os.path.join(data_dir,x)) for x in ['gallery','query']}
query_path = image_datasets['query'].imgs
import numpy as np
query_index = np.argwhere(gallery_label[0]==query_label[0][2])
query_index
# Out:
# [('./rawdata/Market-1501-v15.09.15/pytorch/query/0001/0001_c1s1_001051_00.jpg',
#   0),
#  ('./rawdata/Market-1501-v15.09.15/pytorch/query/0001/0001_c2s1_000301_00.jpg',
#   0),
#  ('./rawdata/Market-1501-v15.09.15/pytorch/query/0001/0001_c3s1_000551_00.jpg',
#   0),
#  ('./rawdata/Market-1501-v15.09.15/pytorch/query/0001/0001_c4s6_000810_00.jpg',
#   0),
#  ('./rawdata/Market-1501-v15.09.15/pytorch/query/0001/0001_c5s1_001426_00.jpg',
#   0),
#  ('./rawdata/Market-1501-v15.09.15/pytorch/query/0001/0001_c6s1_009601_00.jpg',
#   0),
#  ('./rawdata/Market-1501-v15.09.15/pytorch/query/0001/.ipynb_checkpoints/0001_c1s1_001051_00-checkpoint.jpg',
#   0),
#  ('./rawdata/Market-1501-v15.09.15/pytorch/query/0001/.ipynb_checkpoints/0001_c2s1_000301_00-checkpoint.jpg',
#   0),
#  ('./rawdata/Market-1501-v15.09.15/pytorch/query/0001/.ipynb_checkpoints/0001_c3s1_000551_00-checkpoint.jpg',
#   0),
# ...

# %%
## clip model
from transformers import CLIPProcessor, CLIPModel,CLIPVisionModel
model = CLIPModel.from_pretrained("model/clip-vit-base-patch16-finetuned")
processor = CLIPProcessor.from_pretrained("model/clip-vit-base-patch16-finetuned")
vision_model = CLIPVisionModel.from_pretrained("model/clip-vit-base-patch16-finetuned")

# %%
from PIL import Image
images = Image.open('rawdata/customer/images/T8030P132210002A/T8030P132210002A_T8160P01220900B2__20230411110737/T8030P132210002A_T8160P01220900B2__20230411110737_track_04__01/T8030P132210002A__T8160P01220900B2__20230411110737__track_04__0855__1443_442_1591_721.png')

inputs = processor(images=images, return_tensors="pt")
outputs = vision_model(**inputs)
feat = outputs.pooler_output
feat_np = feat.detach().numpy()

# %%
type(feat), feat.shape,type(feat_np), len(feat_np[0])
# Out:
# (torch.Tensor, torch.Size([1, 768]), numpy.ndarray, 768)

# %%
len(feat[0])
# Out:
# 768

# %%
feat
# Out:
# tensor([[-2.7085e-01, -4.7591e-01, -4.0273e-01, -3.7521e-01,  3.5004e-01,
#          -6.8670e-01, -4.3825e-01, -4.5097e-01,  5.9961e-01,  8.1961e-01,
#           8.5711e-01,  1.8772e+00,  1.1633e+00,  5.1832e-01,  1.0779e-01,
#           3.5555e-01, -6.4061e-02, -3.7517e-01, -4.3499e-01, -8.0995e-01,
#           5.6703e-01,  6.3123e-01, -1.6850e-01,  5.9348e-01,  5.7193e-01,
#           1.0222e+00, -8.7484e-01, -2.6398e-01,  7.9267e-01, -5.9919e-01,
#           1.9675e-02, -1.4879e+00,  8.1737e-01, -2.7218e-02,  1.1364e+00,
#          -8.5734e-02,  5.6096e-01,  1.0857e+00,  3.1462e-01,  5.7551e-01,
#          -2.3393e+00,  1.7100e-01, -5.4125e-01,  3.5466e-01,  1.1006e+00,
#          -1.9929e-02, -1.0206e+00,  5.2337e-01,  1.1149e+00, -1.5710e-01,
#           7.3725e-01,  1.5547e+00, -4.4157e-01, -8.3946e-01,  8.2904e-01,
#           1.1315e+00, -3.4957e-02, -5.6130e+00,  1.9027e-01,  7.3944e-01,
#           9.5224e-02, -4.5243e-01,  1.8241e+00,  5.5982e-01,  2.9932e-03,
# ...

# %%
from transformers import AutoImageProcessor, AutoModelForImageClassification
from PIL import Image
import requests

url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)

processor = AutoImageProcessor.from_pretrained("microsoft/swinv2-base-patch4-window8-256")
model = AutoModelForImageClassification.from_pretrained("microsoft/swinv2-base-patch4-window8-256")

inputs = processor(images=image, return_tensors="pt")
outputs = model(**inputs)
logits = outputs.logits
# model predicts one of the 1000 ImageNet classes
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
# Out:
# preprocessor_config.json:   0%|          | 0.00/240 [00:00<?, ?B/s]
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# config.json:   0%|          | 0.00/69.9k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/352M [00:00<?, ?B/s]
# Predicted class: Egyptian cat

# %%
outputs
# Out:
# Swinv2ImageClassifierOutput(loss=None, logits=tensor([[ 2.3274e-01,  1.0125e-03,  5.8190e-01, -1.8281e-01,  2.5451e-01,
#          -5.2935e-01, -7.6467e-01,  2.6886e-01,  1.8874e-01,  2.1775e-01,
#          -4.8729e-01,  2.0495e-01,  2.3607e-01, -3.1827e-01,  2.3141e-01,
#          -1.2445e-01,  1.0415e-01,  1.7005e-01,  3.2600e-01, -4.4850e-01,
#          -4.1986e-02,  1.6084e-01, -3.7433e-01,  9.1912e-02,  9.2282e-02,
#          -3.6974e-01, -8.1160e-02, -1.9161e-01, -2.1427e-01,  2.7615e-02,
#          -1.1810e-02, -2.9153e-01,  3.3718e-01,  3.8885e-01,  2.8430e-01,
#          -2.8716e-02,  3.8499e-01, -4.1751e-02,  7.8744e-02, -1.4230e-02,
#          -2.5671e-01,  3.0338e-01,  5.7383e-01, -3.9447e-01, -6.4480e-03,
#           1.5725e-01, -3.7865e-01, -2.8508e-01, -3.1367e-01, -1.5494e-01,
#          -2.4223e-01,  1.1988e-01, -1.4850e-01, -1.8284e-01,  1.4054e-01,
#          -5.6462e-01, -3.0851e-01,  7.3001e-01, -2.8372e-01,  3.1304e-01,
# ...

# %%
from PIL import Image
import requests
from transformers import (
    VisionTextDualEncoderModel,
    VisionTextDualEncoderProcessor,
    AutoImageProcessor,
    AutoTokenizer,
)

tokenizer = AutoTokenizer.from_pretrained("roberta-base")
#tokenizer = AutoTokenizer.from_pretrained("openai/clip-vit-base-patch16")
image_processor =  AutoImageProcessor.from_pretrained("microsoft/swinv2-base-patch4-window8-256")
processor = VisionTextDualEncoderProcessor(image_processor, tokenizer)
model = VisionTextDualEncoderModel.from_pretrained("model/swinv2-base-roberta-finetuned-1epoch")
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.

# %%
model.vision_model
# Out:
# Swinv2Model(
#   (embeddings): Swinv2Embeddings(
#     (patch_embeddings): Swinv2PatchEmbeddings(
#       (projection): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#     )
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): Swinv2Encoder(
#     (layers): ModuleList(
#       (0): Swinv2Stage(
#         (blocks): ModuleList(
#           (0): Swinv2Layer(
#             (attention): Swinv2Attention(
#               (self): Swinv2SelfAttention(
#                 (continuous_position_bias_mlp): Sequential(
#                   (0): Linear(in_features=2, out_features=512, bias=True)
#                   (1): ReLU(inplace=True)
#                   (2): Linear(in_features=512, out_features=4, bias=False)
#                 )
#                 (query): Linear(in_features=128, out_features=128, bias=True)
#                 (key): Linear(in_features=128, out_features=128, bias=False)
# ...

# %%
import torch
images = [Image.open('./images/LUPerson_test/00_00_0023_00000260.jpg')]
with torch.no_grad():
    inputs = image_processor(
        images=images, return_tensors="pt"
    )
    outputs = model.vision_model(**inputs)

# %%
len(outputs.pooler_output[0])
# Out:
# 1024

# %%
from transformers import AutoImageProcessor, Swinv2Model
import torch
from datasets import load_dataset

image_processor = AutoImageProcessor.from_pretrained("microsoft/swinv2-base-patch4-window8-256")
model = Swinv2Model.from_pretrained("microsoft/swinv2-base-patch4-window8-256")
inputs = image_processor(image, return_tensors="pt")
with torch.no_grad():
    outputs = model(**inputs)
    
len(outputs.pooler_output[0])
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# 1024

# %%
import scipy.io
# 读取 mat 文件
data = scipy.io.loadmat('pytorch_result_ft_ResNet50.mat')
# 获取相应的数据
gallery_feature = data['gallery_f']
gallery_label = data['gallery_label']
gallery_cam = data['gallery_cam']
query_feature = data['query_f']
query_label = data['query_label']
query_cam = data['query_cam']
# 打印数据
print("Gallery Feature:", gallery_feature)
print("Gallery Label:", gallery_label)
print("Gallery Camera:", gallery_cam)
print("Query Feature:", query_feature)
print("Query Label:", query_label)
print("Query Camera:", query_cam)
